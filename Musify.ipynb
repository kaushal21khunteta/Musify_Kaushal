# %%
! unzip 'All Midi Files.zip'
# Out:
# Archive:  All Midi Files.zip
#    creating: All Midi Files/
#   inflating: __MACOSX/._All Midi Files
#    creating: All Midi Files/mozart/
#   inflating: __MACOSX/All Midi Files/._mozart
#    creating: All Midi Files/chopin/
#   inflating: __MACOSX/All Midi Files/._chopin
#    creating: All Midi Files/balakir/
#   inflating: __MACOSX/All Midi Files/._balakir
#    creating: All Midi Files/liszt/
#   inflating: __MACOSX/All Midi Files/._liszt
#    creating: All Midi Files/burgm/
#   inflating: __MACOSX/All Midi Files/._burgm
#    creating: All Midi Files/haydn/
#   inflating: __MACOSX/All Midi Files/._haydn
#    creating: All Midi Files/schumann/
#   inflating: __MACOSX/All Midi Files/._schumann
#    creating: All Midi Files/tschai/
#   inflating: __MACOSX/All Midi Files/._tschai
#    creating: All Midi Files/beeth/
#   inflating: __MACOSX/All Midi Files/._beeth
#    creating: All Midi Files/schubert/
#   inflating: __MACOSX/All Midi Files/._schubert
#    creating: All Midi Files/granados/
#   inflating: __MACOSX/All Midi Files/._granados
#    creating: All Midi Files/albeniz/
#   inflating: __MACOSX/All Midi Files/._albeniz
#    creating: All Midi Files/mendelssohn/
#   inflating: __MACOSX/All Midi Files/._mendelssohn
#    creating: All Midi Files/debussy/
#   inflating: __MACOSX/All Midi Files/._debussy
#    creating: All Midi Files/grieg/
#   inflating: __MACOSX/All Midi Files/._grieg
#    creating: All Midi Files/bach/
#   inflating: __MACOSX/All Midi Files/._bach
#    creating: All Midi Files/muss/
#   inflating: __MACOSX/All Midi Files/._muss
#    creating: All Midi Files/borodin/
#   inflating: __MACOSX/All Midi Files/._borodin
#    creating: All Midi Files/brahms/
#   inflating: __MACOSX/All Midi Files/._brahms
#   inflating: All Midi Files/mozart/mz_570_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_570_1.mid
#   inflating: All Midi Files/mozart/mz_570_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_570_2.mid
#   inflating: All Midi Files/mozart/mz_570_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_570_3.mid
#   inflating: All Midi Files/mozart/mz_545_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_545_1.mid
#   inflating: All Midi Files/mozart/mz_332_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_332_3.mid
#   inflating: All Midi Files/mozart/mz_330_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_330_1.mid
#   inflating: All Midi Files/mozart/mz_332_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_332_2.mid
#   inflating: All Midi Files/mozart/mz_545_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_545_2.mid
#   inflating: All Midi Files/mozart/mz_330_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_330_2.mid
#   inflating: All Midi Files/mozart/mz_330_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_330_3.mid
#   inflating: All Midi Files/mozart/mz_332_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_332_1.mid
#   inflating: All Midi Files/mozart/mz_545_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_545_3.mid
#   inflating: All Midi Files/mozart/mz_331_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_331_2.mid
#   inflating: All Midi Files/mozart/mz_333_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_333_1.mid
#   inflating: All Midi Files/mozart/mz_331_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_331_3.mid
#   inflating: All Midi Files/mozart/mz_331_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_331_1.mid
#   inflating: All Midi Files/mozart/mz_333_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_333_3.mid
#   inflating: All Midi Files/mozart/mz_333_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_333_2.mid
#   inflating: All Midi Files/mozart/mz_311_1.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_311_1.mid
#   inflating: All Midi Files/mozart/mz_311_2.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_311_2.mid
#   inflating: All Midi Files/mozart/mz_311_3.mid
#   inflating: __MACOSX/All Midi Files/mozart/._mz_311_3.mid
#   inflating: All Midi Files/chopin/chpn_op23.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op23.mid
#   inflating: All Midi Files/chopin/chpn-p19.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p19.mid
#   inflating: All Midi Files/chopin/chpn_op7_2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op7_2.mid
#   inflating: All Midi Files/chopin/chpn-p18.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p18.mid
#   inflating: All Midi Files/chopin/chpn-p24.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p24.mid
#   inflating: All Midi Files/chopin/chpn_op7_1.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op7_1.mid
#   inflating: All Midi Files/chopin/chpn-p23.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p23.mid
#   inflating: All Midi Files/chopin/chpn-p9.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p9.mid
#   inflating: All Midi Files/chopin/chpn-p8.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p8.mid
#   inflating: All Midi Files/chopin/chpn-p22.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p22.mid
#   inflating: All Midi Files/chopin/chpn-p20.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p20.mid
#   inflating: All Midi Files/chopin/chpn-p21.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p21.mid
#   inflating: All Midi Files/chopin/chp_op18.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chp_op18.mid
#   inflating: All Midi Files/chopin/chpn_op35_4.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op35_4.mid
#   inflating: All Midi Files/chopin/chpn_op33_2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op33_2.mid
#   inflating: All Midi Files/chopin/chp_op31.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chp_op31.mid
#   inflating: All Midi Files/chopin/chpn_op25_e4.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e4.mid
#   inflating: All Midi Files/chopin/chpn_op35_2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op35_2.mid
#   inflating: All Midi Files/chopin/chpn_op25_e1.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e1.mid
#   inflating: All Midi Files/chopin/chpn_op33_4.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op33_4.mid
#   inflating: All Midi Files/chopin/chpn_op53.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op53.mid
#   inflating: All Midi Files/chopin/chpn_op35_3.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op35_3.mid
#   inflating: All Midi Files/chopin/chpn_op35_1.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op35_1.mid
#   inflating: All Midi Files/chopin/chpn_op25_e2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e2.mid
#   inflating: All Midi Files/chopin/chpn_op25_e3.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e3.mid
#   inflating: All Midi Files/chopin/chpn_op10_e12.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op10_e12.mid
#   inflating: All Midi Files/chopin/chpn_op10_e05.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op10_e05.mid
#   inflating: All Midi Files/chopin/chpn_op10_e01.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op10_e01.mid
#   inflating: All Midi Files/chopin/chpn_op66.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op66.mid
#   inflating: All Midi Files/chopin/chpn-p10.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p10.mid
#   inflating: All Midi Files/chopin/chpn_op25_e12.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e12.mid
#   inflating: All Midi Files/chopin/chpn-p6.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p6.mid
#   inflating: All Midi Files/chopin/chpn-p7.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p7.mid
#   inflating: All Midi Files/chopin/chpn-p11.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p11.mid
#   inflating: All Midi Files/chopin/chpn-p13.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p13.mid
#   inflating: All Midi Files/chopin/chpn_op25_e11.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op25_e11.mid
#   inflating: All Midi Files/chopin/chpn-p5.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p5.mid
#   inflating: All Midi Files/chopin/chpn-p4.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p4.mid
#   inflating: All Midi Files/chopin/chpn-p12.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p12.mid
#   inflating: All Midi Files/chopin/chpn-p16.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p16.mid
#   inflating: All Midi Files/chopin/chpn_op27_2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op27_2.mid
#   inflating: All Midi Files/chopin/chpn-p1.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p1.mid
#   inflating: All Midi Files/chopin/chpn-p17.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p17.mid
#   inflating: All Midi Files/chopin/chpn-p15.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p15.mid
#   inflating: All Midi Files/chopin/chpn-p3.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p3.mid
#   inflating: All Midi Files/chopin/chpn_op27_1.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn_op27_1.mid
#   inflating: All Midi Files/chopin/chpn-p2.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p2.mid
#   inflating: All Midi Files/chopin/chpn-p14.mid
#   inflating: __MACOSX/All Midi Files/chopin/._chpn-p14.mid
#   inflating: All Midi Files/balakir/islamei.mid
#   inflating: __MACOSX/All Midi Files/balakir/._islamei.mid
#   inflating: All Midi Files/liszt/liz_rhap09.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_rhap09.mid
#   inflating: All Midi Files/liszt/liz_et_trans8.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et_trans8.mid
#   inflating: All Midi Files/liszt/liz_donjuan.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_donjuan.mid
#   inflating: All Midi Files/liszt/liz_liebestraum.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_liebestraum.mid
#   inflating: All Midi Files/liszt/liz_et2.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et2.mid
#   inflating: All Midi Files/liszt/liz_et_trans5.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et_trans5.mid
#   inflating: All Midi Files/liszt/liz_et_trans4.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et_trans4.mid
#   inflating: All Midi Files/liszt/liz_et3.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et3.mid
#   inflating: All Midi Files/liszt/liz_rhap12.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_rhap12.mid
#   inflating: All Midi Files/liszt/liz_rhap10.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_rhap10.mid
#   inflating: All Midi Files/liszt/liz_et1.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et1.mid
#   inflating: All Midi Files/liszt/liz_rhap15.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_rhap15.mid
#   inflating: All Midi Files/liszt/liz_et4.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et4.mid
#   inflating: All Midi Files/liszt/liz_et5.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et5.mid
#   inflating: All Midi Files/liszt/liz_rhap02.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_rhap02.mid
#   inflating: All Midi Files/liszt/liz_et6.mid
#   inflating: __MACOSX/All Midi Files/liszt/._liz_et6.mid
#   inflating: All Midi Files/burgm/burg_sylphen.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_sylphen.mid
#   inflating: All Midi Files/burgm/burg_quelle.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_quelle.mid
#   inflating: All Midi Files/burgm/burg_perlen.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_perlen.mid
#   inflating: All Midi Files/burgm/burg_erwachen.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_erwachen.mid
#   inflating: All Midi Files/burgm/burg_spinnerlied.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_spinnerlied.mid
#   inflating: All Midi Files/burgm/burg_geschwindigkeit.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_geschwindigkeit.mid
#   inflating: All Midi Files/burgm/burg_gewitter.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_gewitter.mid
#   inflating: All Midi Files/burgm/burg_agitato.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_agitato.mid
#   inflating: All Midi Files/burgm/burg_trennung.mid
#   inflating: __MACOSX/All Midi Files/burgm/._burg_trennung.mid
#   inflating: All Midi Files/haydn/haydn_43_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_43_1.mid
#   inflating: All Midi Files/haydn/haydn_43_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_43_2.mid
#   inflating: All Midi Files/haydn/haydn_8_4.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_8_4.mid
#   inflating: All Midi Files/haydn/haydn_43_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_43_3.mid
#   inflating: All Midi Files/haydn/haydn_8_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_8_1.mid
#   inflating: All Midi Files/haydn/haydn_8_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_8_3.mid
#   inflating: All Midi Files/haydn/haydn_8_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_8_2.mid
#   inflating: All Midi Files/haydn/haydn_9_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_9_3.mid
#   inflating: All Midi Files/haydn/hay_40_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._hay_40_1.mid
#   inflating: All Midi Files/haydn/haydn_9_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_9_2.mid
#   inflating: All Midi Files/haydn/hay_40_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._hay_40_2.mid
#   inflating: All Midi Files/haydn/haydn_9_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_9_1.mid
#   inflating: All Midi Files/haydn/haydn_7_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_7_3.mid
#   inflating: All Midi Files/haydn/haydn_7_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_7_2.mid
#   inflating: All Midi Files/haydn/haydn_7_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_7_1.mid
#   inflating: All Midi Files/haydn/haydn_33_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_33_1.mid
#   inflating: All Midi Files/haydn/haydn_33_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_33_2.mid
#   inflating: All Midi Files/haydn/haydn_33_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_33_3.mid
#   inflating: All Midi Files/haydn/haydn_35_1.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_35_1.mid
#   inflating: All Midi Files/haydn/haydn_35_2.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_35_2.mid
#   inflating: All Midi Files/haydn/haydn_35_3.mid
#   inflating: __MACOSX/All Midi Files/haydn/._haydn_35_3.mid
#   inflating: All Midi Files/schumann/schum_abegg.mid
#   inflating: __MACOSX/All Midi Files/schumann/._schum_abegg.mid
#   inflating: All Midi Files/schumann/scn68_10.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn68_10.mid
#   inflating: All Midi Files/schumann/scn15_10.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_10.mid
#   inflating: All Midi Files/schumann/scn16_8.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_8.mid
#   inflating: All Midi Files/schumann/scn15_11.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_11.mid
#   inflating: All Midi Files/schumann/scn15_13.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_13.mid
#   inflating: All Midi Files/schumann/scn15_12.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_12.mid
#   inflating: All Midi Files/schumann/scn68_12.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn68_12.mid
#   inflating: All Midi Files/schumann/scn15_8.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_8.mid
#   inflating: All Midi Files/schumann/scn15_9.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_9.mid
#   inflating: All Midi Files/schumann/scn15_7.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_7.mid
#   inflating: All Midi Files/schumann/scn15_6.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_6.mid
#   inflating: All Midi Files/schumann/scn15_4.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_4.mid
#   inflating: All Midi Files/schumann/scn15_5.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_5.mid
#   inflating: All Midi Files/schumann/scn15_1.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_1.mid
#   inflating: All Midi Files/schumann/scn15_2.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_2.mid
#   inflating: All Midi Files/schumann/scn15_3.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn15_3.mid
#   inflating: All Midi Files/schumann/scn16_6.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_6.mid
#   inflating: All Midi Files/schumann/scn16_7.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_7.mid
#   inflating: All Midi Files/schumann/scn16_5.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_5.mid
#   inflating: All Midi Files/schumann/scn16_4.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_4.mid
#   inflating: All Midi Files/schumann/scn16_1.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_1.mid
#   inflating: All Midi Files/schumann/scn16_3.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_3.mid
#   inflating: All Midi Files/schumann/scn16_2.mid
#   inflating: __MACOSX/All Midi Files/schumann/._scn16_2.mid
#   inflating: All Midi Files/tschai/ty_august.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_august.mid
#   inflating: All Midi Files/tschai/ty_dezember.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_dezember.mid
#   inflating: All Midi Files/tschai/ty_november.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_november.mid
#   inflating: All Midi Files/tschai/ty_juni.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_juni.mid
#   inflating: All Midi Files/tschai/ty_april.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_april.mid
#   inflating: All Midi Files/tschai/ty_maerz.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_maerz.mid
#   inflating: All Midi Files/tschai/ty_februar.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_februar.mid
#   inflating: All Midi Files/tschai/ty_januar.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_januar.mid
#   inflating: All Midi Files/tschai/ty_juli.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_juli.mid
#   inflating: All Midi Files/tschai/ty_september.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_september.mid
#   inflating: All Midi Files/tschai/ty_mai.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_mai.mid
#   inflating: All Midi Files/tschai/ty_oktober.mid
#   inflating: __MACOSX/All Midi Files/tschai/._ty_oktober.mid
#   inflating: All Midi Files/beeth/waldstein_1.mid
#   inflating: __MACOSX/All Midi Files/beeth/._waldstein_1.mid
#   inflating: All Midi Files/beeth/beethoven_opus90_2.mid
#   inflating: __MACOSX/All Midi Files/beeth/._beethoven_opus90_2.mid
#   inflating: All Midi Files/beeth/waldstein_2.mid
#   inflating: __MACOSX/All Midi Files/beeth/
mid
#   inflating: __MACOSX/All Midi Files/mendelssohn/._mendel_op30_3.mid
#   inflating: All Midi Files/mendelssohn/mendel_op30_2.mid
#   inflating: __MACOSX/All Midi Files/mendelssohn/._mendel_op30_2.mid
#   inflating: All Midi Files/debussy/DEB_CLAI.MID
#   inflating: __MACOSX/All Midi Files/debussy/._DEB_CLAI.MID
#   inflating: All Midi Files/debussy/deb_prel.mid
#   inflating: __MACOSX/All Midi Files/debussy/._deb_prel.mid
#   inflating: All Midi Files/debussy/DEB_PASS.MID
#   inflating: __MACOSX/All Midi Files/debussy/._DEB_PASS.MID
#   inflating: All Midi Files/debussy/debussy_cc_6.mid
#   inflating: __MACOSX/All Midi Files/debussy/._debussy_cc_6.mid
#   inflating: All Midi Files/debussy/debussy_cc_4.mid
#   inflating: __MACOSX/All Midi Files/debussy/._debussy_cc_4.mid
#   inflating: All Midi Files/debussy/deb_menu.mid
#   inflating: __MACOSX/All Midi Files/debussy/._deb_menu.mid
#   inflating: All Midi Files/debussy/debussy_cc_1.mid
#   inflating: __MACOSX/All Midi Files/debussy/._debussy_cc_1.mid
#   inflating: All Midi Files/debussy/debussy_cc_2.mid
#   inflating: __MACOSX/All Midi Files/debussy/._debussy_cc_2.mid
#   inflating: All Midi Files/debussy/debussy_cc_3.mid
#   inflating: __MACOSX/All Midi Files/debussy/._debussy_cc_3.mid
#   inflating: All Midi Files/grieg/grieg_kobold.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_kobold.mid
#   inflating: All Midi Files/grieg/grieg_halling.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_halling.mid
#   inflating: All Midi Files/grieg/grieg_waechter.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_waechter.mid
#   inflating: All Midi Files/grieg/grieg_walzer.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_walzer.mid
#   inflating: All Midi Files/grieg/grieg_butterfly.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_butterfly.mid
#   inflating: All Midi Files/grieg/grieg_wanderer.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_wanderer.mid
#   inflating: All Midi Files/grieg/grieg_album.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_album.mid
#   inflating: All Midi Files/grieg/grieg_voeglein.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_voeglein.mid
#   inflating: All Midi Files/grieg/grieg_spring.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_spring.mid
#   inflating: All Midi Files/grieg/grieg_berceuse.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_berceuse.mid
#   inflating: All Midi Files/grieg/grieg_brooklet.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_brooklet.mid
#   inflating: All Midi Files/grieg/grieg_once_upon_a_time.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_once_upon_a_time.mid
#   inflating: All Midi Files/grieg/grieg_march.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_march.mid
#   inflating: All Midi Files/grieg/grieg_zwerge.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_zwerge.mid
#   inflating: All Midi Files/grieg/grieg_wedding.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_wedding.mid
#   inflating: All Midi Files/grieg/grieg_elfentanz.mid
#   inflating: __MACOSX/All Midi Files/grieg/._grieg_elfentanz.mid
#   inflating: All Midi Files/bach/bach_847.mid
#   inflating: __MACOSX/All Midi Files/bach/._bach_847.mid
#   inflating: All Midi Files/bach/bach_846.mid
#   inflating: __MACOSX/All Midi Files/bach/._bach_846.mid
#   inflating: All Midi Files/bach/bach_850.mid
#   inflating: __MACOSX/All Midi Files/bach/._bach_850.mid
#   inflating: All Midi Files/muss/muss_2.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_2.mid
#   inflating: All Midi Files/muss/muss_3.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_3.mid
#   inflating: All Midi Files/muss/muss_1.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_1.mid
#   inflating: All Midi Files/muss/muss_4.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_4.mid
#   inflating: All Midi Files/muss/muss_5.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_5.mid
#   inflating: All Midi Files/muss/muss_7.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_7.mid
#   inflating: All Midi Files/muss/muss_6.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_6.mid
#   inflating: All Midi Files/muss/muss_8.mid
#   inflating: __MACOSX/All Midi Files/muss/._muss_8.mid
#   inflating: All Midi Files/borodin/bor_ps1.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps1.mid
#   inflating: All Midi Files/borodin/bor_ps2.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps2.mid
#   inflating: All Midi Files/borodin/bor_ps3.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps3.mid
#   inflating: All Midi Files/borodin/bor_ps7.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps7.mid
#   inflating: All Midi Files/borodin/bor_ps6.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps6.mid
#   inflating: All Midi Files/borodin/bor_ps4.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps4.mid
#   inflating: All Midi Files/borodin/bor_ps5.mid
#   inflating: __MACOSX/All Midi Files/borodin/._bor_ps5.mid
#   inflating: All Midi Files/brahms/brahms_opus1_4.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus1_4.mid
#   inflating: All Midi Files/brahms/brahms_opus1_2.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus1_2.mid
#   inflating: All Midi Files/brahms/br_rhap.mid
#   inflating: __MACOSX/All Midi Files/brahms/._br_rhap.mid
#   inflating: All Midi Files/brahms/brahms_opus1_3.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus1_3.mid
#   inflating: All Midi Files/brahms/brahms_opus1_1.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus1_1.mid
#   inflating: All Midi Files/brahms/BR_IM6.MID
#   inflating: __MACOSX/All Midi Files/brahms/._BR_IM6.MID
#   inflating: All Midi Files/brahms/brahms_opus117_1.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus117_1.mid
#   inflating: All Midi Files/brahms/br_im5.mid
#   inflating: __MACOSX/All Midi Files/brahms/._br_im5.mid
#   inflating: All Midi Files/brahms/brahms_opus117_2.mid
#   inflating: __MACOSX/All Midi Files/brahms/._brahms_opus117_2.mid
#   inflating: All Midi Files/brahms/br_im2.mid
#   inflating: __MACOSX/All Midi Files/brahms/._br_im2.mid

# %% [markdown]
# # Importing

# %%
from music21 import *
import glob
from tqdm import tqdm
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras.layers import LSTM,Dense,Input,Dropout
from tensorflow.keras.models import Sequential,Model,load_model 
from sklearn.model_selection import train_test_split

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import os

# %% [markdown]
# # Data Preparation

# %%
def read_files(file):
    notes=[]
    notes_to_parse=None
    #parse the midi file
    midi=converter.parse(file)
    #seperate all instruments from the file
    instrmt=instrument.partitionByInstrument(midi)
    for part in instrmt.parts:
        #fetch data only of Piano instrument
        if 'Piano' in str(part):
            notes_to_parse=part.recurse()
            for element in notes_to_parse:
                if type(element)==note.Note:
                    notes.append(str(element.pitch))
                elif type(element)==chord.Chord:
                    notes.append('.'.join(str(n) for n in element.normalOrder))
    return notes
#retrieve paths recursively from inside the directories/files
file_path=['mozart'] 
all_files=glob.glob('/content/All Midi Files/'+ file_path[0]+'/*.mid',recursive=True)
notes_array = np.array([read_files(i) for i in tqdm(all_files,position=0,leave=True)])
# Out:
# 100%|██████████| 21/21 [02:13<00:00,  6.38s/it]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
#unique notes
notess = sum(notes_array,[]) 
unique_notes = list(set(notess))
print("Unique Notes:",len(unique_notes))

#notes with their frequency
freq=dict(map(lambda x: (x,notess.count(x)),unique_notes))

#get the threshold frequency
print("\nFrequency notes")
for i in range(30,100,20):
  print(i,":",len(list(filter(lambda x:x[1]>=i,freq.items()))))

#filter notes greater than threshold i.e. 70
freq_notes=dict(filter(lambda x:x[1]>=70,freq.items()))

#create new notes using the frequent notes
new_notes=[[i for i in j if i in freq_notes] for j in notes_array]

#dictionary having key as note index and value as note
ind2note=dict(enumerate(freq_notes))

#dictionary having key as note and value as note index
note2ind=dict(map(reversed,ind2note.items()))
# Out:
# Unique Notes: 197
#
# Frequency notes
# 30 : 109
# 50 : 94
# 70 : 83
# 90 : 75

# %%
timesteps=50

#store values of input and output
x=[] ; y=[]

for i in new_notes:
  for j in range(0,len(i)-timesteps):
    #input will be the current index + timestep
    #output will be the next index after timestep
    inp=i[j:j+timesteps] ; out=i[j+timesteps]

    #append the index value of respective notes 
    x.append(list(map(lambda x:note2ind[x],inp)))
    y.append(note2ind[out])

x_new=np.array(x) 
y_new=np.array(y)

# %%
#reshape input and output for the model
x_new = np.reshape(x_new,(len(x_new),timesteps,1))
y_new = np.reshape(y_new,(-1,1))

#split the input and value into training and testing sets
#80% for training and 20% for testing sets
x_train,x_test,y_train,y_test = train_test_split(x_new,y_new,test_size=0.2,random_state=42)

# %% [markdown]
# # Model Buiding

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.compat.v1.Session(config=config)

# %%
#create the model
model = Sequential()
#create two stacked LSTM layer with the latent dimension of 256
model.add(LSTM(256,return_sequences=True,input_shape=(x_new.shape[1],x_new.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(256,activation='relu'))

#fully connected layer for the output with softmax activation
model.add(Dense(len(note2ind),activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 256)           264192
#
#  dropout (Dropout)           (None, 50, 256)           0
#
#  lstm_1 (LSTM)               (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dense_1 (Dense)             (None, 83)                21331
#
# =================================================================
# Total params: 876,627
# Trainable params: 876,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile the model using Adam optimizer
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

#train the model on training sets and validate on testing sets
with tf.device('/gpu:0'):
    model.fit(
        x_train,y_train,
        batch_size=128,epochs=80, 
        validation_data=(x_test,y_test))
# Out:
# Epoch 1/80
# 354/354 [==============================] - 14s 20ms/step - loss: 3.8702 - accuracy: 0.0608 - val_loss: 3.7895 - val_accuracy: 0.0748
# Epoch 2/80
# 354/354 [==============================] - 6s 17ms/step - loss: 3.7472 - accuracy: 0.0842 - val_loss: 3.6936 - val_accuracy: 0.0954
# Epoch 3/80
# 354/354 [==============================] - 6s 17ms/step - loss: 3.6167 - accuracy: 0.1061 - val_loss: 3.5553 - val_accuracy: 0.1122
# Epoch 4/80
# 354/354 [==============================] - 6s 17ms/step - loss: 3.4680 - accuracy: 0.1291 - val_loss: 3.3850 - val_accuracy: 0.1477
# Epoch 5/80
# 354/354 [==============================] - 6s 17ms/step - loss: 3.2844 - accuracy: 0.1608 - val_loss: 3.2515 - val_accuracy: 0.1672
# Epoch 6/80
# 354/354 [==============================] - 6s 18ms/step - loss: 3.1007 - accuracy: 0.1941 - val_loss: 3.1150 - val_accuracy: 0.1990
# Epoch 7/80
# 354/354 [==============================] - 6s 18ms/step - loss: 2.9257 - accuracy: 0.2316 - val_loss: 2.9823 - val_accuracy: 0.2270
# Epoch 8/80
# 354/354 [==============================] - 6s 17ms/step - loss: 2.7507 - accuracy: 0.2668 - val_loss: 2.8545 - val_accuracy: 0.2479
# Epoch 9/80
# 354/354 [==============================] - 6s 18ms/step - loss: 2.5842 - accuracy: 0.3022 - val_loss: 2.7215 - val_accuracy: 0.2810
# Epoch 10/80
# 354/354 [==============================] - 6s 18ms/step - loss: 2.4288 - accuracy: 0.3388 - val_loss: 2.6394 - val_accuracy: 0.3024
# Epoch 11/80
# 354/354 [==============================] - 6s 18ms/step - loss: 2.2730 - accuracy: 0.3744 - val_loss: 2.5222 - val_accuracy: 0.3324
# Epoch 12/80
# 354/354 [==============================] - 6s 18ms/step - loss: 2
80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.4156 - accuracy: 0.8648 - val_loss: 1.7859 - val_accuracy: 0.7378
# Epoch 69/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.4073 - accuracy: 0.8691 - val_loss: 1.7685 - val_accuracy: 0.7385
# Epoch 70/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.4120 - accuracy: 0.8675 - val_loss: 1.7825 - val_accuracy: 0.7392
# Epoch 71/80
# 354/354 [==============================] - 7s 19ms/step - loss: 0.4026 - accuracy: 0.8701 - val_loss: 1.7766 - val_accuracy: 0.7409
# Epoch 72/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.3909 - accuracy: 0.8729 - val_loss: 1.7828 - val_accuracy: 0.7398
# Epoch 73/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.4006 - accuracy: 0.8706 - val_loss: 1.7864 - val_accuracy: 0.7436
# Epoch 74/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.3920 - accuracy: 0.8731 - val_loss: 1.8070 - val_accuracy: 0.7387
# Epoch 75/80
# 354/354 [==============================] - 7s 19ms/step - loss: 0.4016 - accuracy: 0.8727 - val_loss: 1.8049 - val_accuracy: 0.7414
# Epoch 76/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.3991 - accuracy: 0.8726 - val_loss: 1.8160 - val_accuracy: 0.7425
# Epoch 77/80
# 354/354 [==============================] - 6s 18ms/step - loss: 0.3883 - accuracy: 0.8761 - val_loss: 1.8314 - val_accuracy: 0.7388
# Epoch 78/80
# 354/354 [==============================] - 6s 18ms/step - loss: 0.3821 - accuracy: 0.8767 - val_loss: 1.8041 - val_accuracy: 0.7441
# Epoch 79/80
# 354/354 [==============================] - 7s 19ms/step - loss: 0.3726 - accuracy: 0.8800 - val_loss: 1.8376 - val_accuracy: 0.7417
# Epoch 80/80
# 354/354 [==============================] - 7s 18ms/step - loss: 0.3797 - accuracy: 0.8773 - val_loss: 1.8380 - val_accuracy: 0.7420

# %%
model.save("MOD")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: MOD/assets
# INFO:tensorflow:Assets written to: MOD/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f98bd1b9550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f98d1a7a390> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
model=load_model("MOD")
#generate random index
index = np.random.randint(0,len(x_test)-1)
#get the data of generated index from x_test
music_pattern = x_test[index]

out_pred=[] #it will store predicted notes

#iterate till 200 note is generated
for i in range(200):

  #reshape the music pattern 
  music_pattern = music_pattern.reshape(1,len(music_pattern),1)
  
  #get the maximum probability value from the predicted output
  pred_index = np.argmax(model.predict(music_pattern))
  #get the note using predicted index and
  #append to the output prediction list
  out_pred.append(ind2note[pred_index])
  music_pattern = np.append(music_pattern,pred_index)
  
  #update the music pattern with one timestep ahead
  music_pattern = music_pattern[1:]

# %%
output_notes = []
for offset,pattern in enumerate(out_pred):
  #if pattern is a chord instance
  if ('.' in pattern) or pattern.isdigit():
    #split notes from the chord
    notes_in_chord = pattern.split('.')
    notes = []
    for current_note in notes_in_chord:
        i_curr_note=int(current_note)
        #cast the current note to Note object and
        #append the current note 
        new_note = note.Note(i_curr_note)
        new_note.storedInstrument = instrument.Piano()
        notes.append(new_note)
    
    #cast the current note to Chord object
    #offset will be 1 step ahead from the previous note
    #as it will prevent notes to stack up 
    new_chord = chord.Chord(notes)
    new_chord.offset = offset
    output_notes.append(new_chord)
  
  else:
    #cast the pattern to Note object apply the offset and 
    #append the note
    new_note = note.Note(pattern)
    new_note.offset = offset
    new_note.storedInstrument = instrument.Piano()
    output_notes.append(new_note)

#save the midi file 
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='AI_composed_music.mid')
# Out:
# 'AI_composed_music.mid'
